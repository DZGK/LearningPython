# %%
import pandas as pd
import numpy as np

df = pd.read_csv("bank.csv")

# bank_data

# 先頭の 5件を表示
df.head()

# 末尾の 5件を表示
# df.tail()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
import pandas as pd
import numpy as np

# データフレーム生成
df = pd.read_csv("bank.csv")

# 配列名.iloc[行のスライス指定][列のスライス指定]
# 配列名.iloc[行のスライス指定, 列のスライス指定]
# df.iloc[1, 3]


# 0番目から 4番目まで
# df.iloc[0:3, 0:3]

# [start:end:incremental]
df.iloc[:11:2, :11:2]
# Out:
#     age  marital default housing   contact month
# 0    30  married      no      no  cellular   oct
# 2    35   single      no     yes  cellular   apr
# 4    59  married      no     yes   unknown   may
# 6    36  married      no     yes  cellular   may
# 8    41  married      no     yes   unknown   may
# 10   39  married      no     yes   unknown   may

# %%
import pandas as pd
import numpy as np

# データフレーム生成
df = pd.read_csv("bank.csv")

# 列名で出力
df.loc[:10, ["age", "marital", "month"]]
# Out:
#     age  marital month
# 0    30  married   oct
# 1    33  married   may
# 2    35   single   apr
# 3    30  married   jun
# 4    59  married   may
# 5    35   single   feb
# 6    36  married   may
# 7    39  married   may
# 8    41  married   may
# 9    43  married   apr
# 10   39  married   may

# %%
import pandas as pd
import numpy as np

# データフレーム生成
df = pd.read_csv("bank.csv")

# クエリの実行
# ダブルクォートの位置に注意する。右のように項目毎に囲むと思っていたのと異なる動作をする。　df.query("age >=35" and "marital == 'single'")
df.query("age >=35 and marital == 'single'")
# Out:
#       age           job marital  education default  balance housing loan  \
# 2      35    management  single   tertiary      no     1350     yes   no
# 5      35    management  single   tertiary      no      747      no   no
# 17     37        admin.  single   tertiary      no     2317     yes   no
# 22     44      services  single  secondary      no      106      no   no
# 40     38    management  single   tertiary      no    11971     yes   no
# ...   ...           ...     ...        ...     ...      ...     ...  ...
# 4465   38    management  single   tertiary      no      623      no   no
# 4479   39        admin.  single  secondary      no      163     yes   no
# 4491   35   blue-collar  single  secondary      no        0     yes   no
# 4504   42   blue-collar  single  secondary      no     1080     yes  yes
# 4520   44  entrepreneur  single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
import pandas as pd
import numpy as np

# データフレーム生成
df = pd.read_csv("bank.csv")

# クエリの実行
df[df["age"] >=35]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 2      35     management   single   tertiary      no     1350     yes   no
# 4      59    blue-collar  married  secondary      no        0     yes   no
# 5      35     management   single   tertiary      no      747      no   no
# 6      36  self-employed  married   tertiary      no      307     yes   no
# 7      39     technician  married  secondary      no      147     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4513   49    blue-collar  married  secondary      no      322      no   no
# 4514   38    blue-collar  married  secondary      no     1205     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
import pandas as pd
import numpy as np

# データフレーム生成
df = pd.read_csv("bank.csv")

# Pandas の DataFrame から NumPy の ndarrayへの変換
# カラム名の取得
ndarray_columns = df.columns.values
# データの取得
ndarray = df.values
print(type(ndarray))
print(ndarray_columns, ndarray)


# ndarray から DataFrame への変換
df2 = pd.DataFrame(data=ndarray, columns=ndarray_columns)
df2
# Out:
# <class 'numpy.ndarray'>
# ['age' 'job' 'marital' 'education' 'default' 'balance' 'housing' 'loan'
#  'contact' 'day' 'month' 'duration' 'campaign' 'pdays' 'previous'
#  'poutcome' 'y'] [[30 'unemployed' 'married' ... 0 'unknown' 'no']
#  [33 'services' 'married' ... 4 'failure' 'no']
#  [35 'management' 'single' ... 1 'failure' 'no']
#  ...
#  [57 'technician' 'married' ... 0 'unknown' 'no']
#  [28 'blue-collar' 'married' ... 3 'other' 'no']
#  [44 'entrepreneur' 'single' ... 7 'other' 'no']]
#      age            job  marital  education default balance housing loan  \
# 0     30     unemployed  married    primary      no    1787      no   no
# 1     33       services  married  secondary      no    4789     yes  yes
# 2     35     management   single   tertiary      no    1350     yes   no
# 3     30     management  married   tertiary      no    1476     yes  yes
# 4     59    blue-collar  married  secondary      no       0     yes   no
# ...
